# %%
# STEP 0: Setup for Google Colab
# !pip install ipywidgets --quiet

# ✅ NEW: Clone your GitHub repo and navigate into it
import os, sys, shutil

# Remove old copy if it exists
if os.path.exists("RealOrAI-DogDetector"):
    shutil.rmtree("RealOrAI-DogDetector")

# !git clone https://github.com/zhaoq23/RealOrAI-DogDetector.git

# Change directory to repo and add to Python path
os.chdir("RealOrAI-DogDetector")
sys.path.append(".")


import torch
from IPython.display import display
import ipywidgets as widgets
from models import BayesianMLP

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Cloning into 'RealOrAI-DogDetector'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 151 (delta 40), reused 10 (delta 2), pack-reused 45 (from 1)
# Receiving objects: 100% (151/151), 105.87 MiB | 23.29 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %%
# !pip install ipywidgets --quiet

import torch
from torch.utils.data import DataLoader
from IPython.display import display
import ipywidgets as widgets
from models import BayesianMLP

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def load_model(model_path="plusdiff_model.pt"):
    model = BayesianMLP()
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()
    return model

# %%
def classify_feature_tensor(tensor, model):
    tensor = tensor.to(device)
    with torch.no_grad():
        output = model(tensor)
        probs = torch.sigmoid(output).squeeze()

        # If only one item, make it iterable
        if probs.dim() == 0:
            probs = probs.unsqueeze(0)

        for i, p in enumerate(probs):
            label = "AI-GENERATED 🤖" if p >= 0.5 else "REAL 🐶"
            print(f"Image {i+1}: {label}  |  Probability: {p:.2f}")

# %%
upload = widgets.FileUpload(accept='.pt', multiple=False)

def on_upload_change(change):
    if upload.value:
        file_info = next(iter(upload.value.values()))
        with open("temp.pt", "wb") as f:
            f.write(file_info['content'])

        # Load the .pt file and extract features
        data = torch.load("temp.pt")
        if isinstance(data, tuple):  # (features, label)
            tensor = data[0]
        else:
            tensor = data

        if len(tensor.shape) == 1:
            tensor = tensor.unsqueeze(0)  # Add batch dimension if needed

        # ✅ Add this padding fix
        if tensor.shape[1] == 384:
            padding = torch.zeros((tensor.shape[0], 1))
            tensor = torch.cat([tensor, padding], dim=1)

        # Load model and classify
        model = load_model()
        classify_feature_tensor(tensor, model)

upload.observe(on_upload_change, names='value')
display(upload)
# Out:
# FileUpload(value={}, accept='.pt', description='Upload')
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     618         # be locked when the hold_trait_notification context manager is
#     619         # released and notifications are fired.
# --> 620         with self._lock_property(**sync_data), self.hold_trait_notifications():
#     621             for name in sync_data:
#     622                 if name in self.keys:
#
# /usr/lib/python3.11/contextlib.py in __exit__(self, typ, value, traceback)
#     142         if typ is None:
#     143             try:
# --> 144                 next(self.gen)
#     145             except StopIteration:
#     146                 return False
#
# /usr/local/lib/python3.11/dist-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1496                 for changes in cache.values():
#    1497                     for change in changes:
# -> 1498                         self.notify_change(change)
#    1499
#    1500     def _notify_trait(self, name, old_value, new_value):
#
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     684                 # Send new state to front-end
#     685                 self.send_state(key=name)
# --> 686         super(Widget, self).notify_change(change)
#     687
#     688     def __repr__(self):
#
# /usr/local/lib/python3.11/dist-packages/traitlets/traitlets.py in notify_change(self, change)
#    1511     def notify_change(self, change):
#    1512         """Notify observers of a change event"""
# -> 1513         return self._notify_observers(change)
#    1514
#    1515     def _notify_observers(self, event):
#
# /usr/local/lib/python3.11/dist-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1558                 c = getattr(self, c.name)
#    1559
# -> 1560             c(event)
#    1561
#    1562     def _add_notifiers(self, handler, name, type):
#
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget_upload.py in on_incr_counter(self, change)
#      62             name = metadata['name']
#      63             res[name] = {'metadata': metadata, 'content': content}
# ---> 64         self.set_trait('value', res)
#      65
#      66     @default('description')
#
# /usr/local/lib/python3.11/dist-packages/traitlets/traitlets.py in set_trait(self, name, value)
#    1736             raise TraitError(f"Class {cls.__name__} does not have a trait named {name}")
#    1737         else:
# -> 1738             getattr(cls, name).set(self, value)
#    1739
#    1740     @classmethod
#
# /usr/local/lib/python3.11/dist-packages/traitlets/traitlets.py in set(self, obj, value)
#     716             # we explicitly compare silent to True just in case the equality
#     717             # comparison above returns something other than True/False
# --> 718             obj._notify_trait(self.name, old_value, new_value)
#     719
#     720     def __set__(self, obj, value):
#
# /usr/local/lib/python3.11/dist-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1499
#    1500     def _notify_trait(self, name, old_value, new_value):
# -> 1501         self.notify_change(
#    1502             Bunch(
#    1503                 name=name,
#
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     684                 # Send new state to front-end
#     685                 self.send_state(key=name)
# --> 686         super(Widget, self).notify_change(change)
#     687
#     688     def __repr__(self):
#
# /usr/local/lib/python3.11/dist-packages/traitlets/traitlets.py in notify_change(self, change)
#    1511     def notify_change(self, change):
#    1512         """Notify observers of a change event"""
# -> 1513         return self._notify_observers(change)
#    1514
#    1515     def _notify_observers(self, event):
#
# /usr/local/lib/python3.11/dist-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1558                 c = getattr(self, c.name)
#    1559
# -> 1560             c(event)
#    1561
#    1562     def _add_notifiers(self, handler, name, type):
#
# <ipython-input-36-ae8a349e6693> in on_upload_change(change)
#       8
#       9         # Load the .pt file and extract features
# ---> 10         data = torch.load("temp.pt")
#      11         if isinstance(data, tuple):  # (features, label)
#      12             tensor = data[0]
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1460                 if weights_only:
#    1461                     try:
# -> 1462                         return _load(
#    1463                             opened_zipfile,
#    1464                             map_location,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1962     global _serialization_tls
#    1963     _serialization_tls.map_location = map_location
# -> 1964     result = unpickler.load()
#    1965     _serialization_tls.map_location = None
#    1966
#
# /usr/local/lib/python3.11/dist-packages/torch/_weights_only_unpickler.py in load(self)
#     510                         f"Only persistent_load of storage is allowed, but got {pid[0]}"
#     511                     )
# --> 512                 self.append(self.persistent_load(pid))
#     513             elif key[0] in [BINGET[0], LONG_BINGET[0]]:
#     514                 idx = (read(1) if key[0] == BINGET[0] else unpack("<I", read(4)))[0]
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in persistent_load(saved_id)
#    1926         else:
#    1927             nbytes = numel * torch._utils._element_size(dtype)
# -> 1928             typed_storage = load_tensor(
#    1929                 dtype, nbytes, key, _maybe_decode_ascii(location)
#    1930             )
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load_tensor(dtype, numel, key, location)
#    1898         # stop wrapping with TypedStorage
#    1899         typed_storage = torch.storage.TypedStorage(
# -> 1900             wrap_storage=restore_location(storage, location),
#    1901             dtype=dtype,
#    1902             _internal=True,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in default_restore_location(storage, location)
#     691     """
#     692     for _, _, fn in _package_registry:
# --> 693         result = fn(storage, location)
#     694         if result is not None:
#     695             return result
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _deserialize(backend_name, obj, location)
#     629         backend_name = torch._C._get_privateuse1_backend_name()
#     630     if location.startswith(backend_name):
# --> 631         device = _validate_device(location, backend_name)
#     632         return obj.to(device=device)
#     633
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _validate_device(location, backend_name)
#     598         device_index = device.index if device.index else 0
#     599     if hasattr(device_module, "is_available") and not device_module.is_available():
# --> 600         raise RuntimeError(
#     601             f"Attempting to deserialize object on a {backend_name.upper()} "
#     602             f"device but torch.{backend_name}.is_available() is False. "
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.
# Image 1: AI-GENERATED 🤖  |  Probability: 1.00
# Image 2: AI-GENERATED 🤖  |  Probability: 1.00
# Image 3: AI-GENERATED 🤖  |  Probability: 1.00
# Image 4: AI-GENERATED 🤖  |  Probability: 1.00
# Image 5: AI-GENERATED 🤖  |  Probability: 1.00
# Image 6: AI-GENERATED 🤖  |  Probability: 1.00
# Image 7: AI-GENERATED 🤖  |  Probability: 1.00
# Image 8: AI-GENERATED 🤖  |  Probability: 1.00
# Image 9: AI-GENERATED 🤖  |  Probability: 1.00
# Image 10: AI-GENERATED 🤖  |  Probability: 1.00
# Image 11: AI-GENERATED 🤖  |  Probability: 0.97
# Image 12: AI-GENERATED 🤖  |  Probability: 1.00
# Image 13: AI-GENERATED 🤖  |  Probability: 1.00
# Image 14: AI-GENERATED 🤖  |  Probability: 1.00
# Image 15: AI-GENERATED 🤖  |  Probability: 1.00
# Image 16: AI-GENERATED 🤖  |  Probability: 0.92
# Image 17: AI-GENERATED 🤖  |  Probability: 1.00
# Image 18: AI-GENERATED 🤖  |  Probability: 1.00
# Image 19: AI-GENERATED 🤖  |  Probability: 1.00
# Image 20: AI-GENERATED 🤖  |  Probability: 1.00
# Image 21: AI-GENERATED 🤖  |  Probability: 0.92
# Image 22: AI-GENERATED 🤖  |  Probability: 1.00
# Image 23: AI-GENERATED 🤖  |  Probability: 1.00
# Image 24: AI-GENERATED 🤖  |  Probability: 1.00
# Image 25: AI-GENERATED 🤖  |  Probability: 0.99
# Image 26: AI-GENERATED 🤖  |  Probability: 0.91
# Image 27: AI-GENERATED 🤖  |  Probability: 1.00
# Image 28: AI-GENERATED 🤖  |  Probability: 1.00
# Image 29: AI-GENERATED 🤖  |  Probability: 1.00
# Image 591: AI-GENERATED 🤖  |  Probability: 0.99
# Image 592: AI-GENERATED 🤖  |  Probability: 1.00
# Image 593: AI-GENERATED 🤖  |  Probability: 1.00
# Image 594: AI-GENERATED 🤖  |  Probability: 1.00
# Image 595: AI-GENERATED 🤖  |  Probability: 0.99
# Image 596: AI-GENERATED 🤖  |  Probability: 1.00
# Image 597: AI-GENERATED 🤖  |  Probability: 0.97
# Image 598: AI-GENERATED 🤖  |  Probability: 1.00
# Image 599: AI-GENERATED 🤖  |  Probability: 0.98
# Image 600: AI-GENERATED 🤖  |  Probability: 0.98
# Image 601: REAL 🐶  |  Probability: 0.00
# Image 602: REAL 🐶  |  Probability: 0.00
# Image 603: REAL 🐶  |  Probability: 0.00
# Image 604: REAL 🐶  |  Probability: 0.00
# Image 605: REAL 🐶  |  Probability: 0.00
# Image 606: REAL 🐶  |  Probability: 0.00
# Image 607: REAL 🐶  |  Probability: 0.00
# Image 608: REAL 🐶  |  Probability: 0.00
# Image 609: REAL 🐶  |  Probability: 0.00
# Image 610: REAL 🐶  |  Probability: 0.01
# Image 611: REAL 🐶  |  Probability: 0.00
# Image 612: REAL 🐶  |  Probability: 0.00
# Image 613: REAL 🐶  |  Probability: 0.00
# Image 614: REAL 🐶  |  Probability: 0.00
# Image 615: REAL 🐶  |  Probability: 0.00
# Image 616: REAL 🐶  |  Probability: 0.00
# Image 617: REAL 🐶  |  Probability: 0.00
# Image 618: REAL 🐶  |  Probability: 0.00
# Image 619: REAL 🐶  |  Probability: 0.00
# Image 620: REAL 🐶  |  Probability: 0.00
# Image 621: REAL 🐶  |  Probability: 0.00
# Image 622: REAL 🐶  |  Probability: 0.00
# Image 623: REAL 🐶  |  Probability: 0.00
# Image 624: REAL 🐶  |  Probability: 0.00
# Image 625: REAL 🐶  |  Probability: 0.00
# Image 626: REAL 🐶  |  Probability: 0.00
# Image 627: REAL 🐶  |  Probability: 0.00
# Image 628: REAL 🐶  |  Probability: 0.00
# Image 629: REAL 🐶  |  Probability: 0.00
# Image 630: REAL 🐶  |  Probability: 0.00
# Image 631: REAL 🐶  |  Probability: 0.00
# Image 632: REAL 🐶  |  Probability: 0.00
# Image 633: REAL 🐶  |  Probability: 0.00
# Image 634: REAL 🐶  |  Probability: 0.00
# Image 635: REAL 🐶  |  Probability: 0.00
# Image 636: REAL 🐶  |  Probability: 0.00
# Image 637: REAL 🐶  |  Probability: 0.00
# Image 638: REAL 🐶  |  Probability: 0.00
# Image 639: REAL 🐶  |  Probability: 0.00
# Image 640: REAL 🐶  |  Probability: 0.00
# Image 641: REAL 🐶  |  Probability: 0.00
# Image 642: REAL 🐶  |  Probability: 0.00
# Image 643: REAL 🐶  |  Probability: 0.00
# Image 644: REAL 🐶  |  Probability: 0.00
# Image 645: REAL 🐶  |  Probability: 0.00
# Image 646: REAL 🐶  |  Probability: 0.00
# Image 647: REAL 🐶  |  Probability: 0.00
# Image 648: REAL 🐶  |  Probability: 0.00
# Image 649: REAL 🐶  |  Probability: 0.00
# Image 650: REAL 🐶  |  Probability: 0.00
# Image 651: REAL 🐶  |  Probability: 0.00
# Image 652: REAL 🐶  |  Probability: 0.00
# Image 653: REAL 🐶  |  Probability: 0.00
# Image 654: REAL 🐶  |  Probability: 0.00
# Image 655: REAL 🐶  |  Probability: 0.00
# Image 656: REAL 🐶  |  Probability: 0.00
# Image 657: REAL 🐶  |  Probability: 0.00
# Image 658: REAL 🐶  |  Probability: 0.00
# Image 659: REAL 🐶  |  Probability: 0.00
# Image 660: REAL 🐶  |  Probability: 0.00
# Image 661: REAL 🐶  |  Probability: 0.00
# Image 662: REAL 🐶  |  Probability: 0.00
# Image 663: REAL 🐶  |  Probability: 0.00
# Image 664: REAL 🐶  |  Probability: 0.00
# Image 665: REAL 🐶  |  Probability: 0.00
# Image 666: REAL 🐶  |  Probability: 0.00
# Image 667: REAL 🐶  |  Probability: 0.00
# Image 668: REAL 🐶  |  Probability: 0.00
# Image 669: REAL 🐶  |  Probability: 0.00
# Image 670: REAL 🐶  |  Probability: 0.00
# Image 671: REAL 🐶  |  Probability: 0.05
# Image 672: REAL 🐶  |  Probability: 0.00
# Image 673: REAL 🐶  |  Probability: 0.00
# Image 674: REAL 🐶  |  Probability: 0.00
# Image 675: REAL 🐶  |  Probability: 0.00
# Image 676: REAL 🐶  |  Probability: 0.00
# Image 677: REAL 🐶  |  Probability: 0.00
# Image 678: REAL 🐶  |  Probability: 0.00
# Image 679: REAL 🐶  |  Probability: 0.00
# Image 680: REAL 🐶  |  Probability: 0.00
# Image 681: REAL 🐶  |  Probability: 0.00
# Image 682: REAL 🐶  |  Probability: 0.00
# Image 683: REAL 🐶  |  Probability: 0.00
# Image 684: REAL 🐶  |  Probability: 0.00
# Image 685: REAL 🐶  |  Probability: 0.00
# Image 686: REAL 🐶  |  Probability: 0.00
# Image 687: REAL 🐶  |  Probability: 0.01
# Image 688: REAL 🐶  |  Probability: 0.00
# Image 689: REAL 🐶  |  Probability: 0.00
# Image 690: REAL 🐶  |  Probability: 0.00
# Image 691: REAL 🐶  |  Probability: 0.00
# Image 692: REAL 🐶  |  Probability: 0.00
# Image 693: REAL 🐶  |  Probability: 0.00
# Image 694: REAL 🐶  |  Probability: 0.04
# Image 695: REAL 🐶  |  Probability: 0.00
# Image 696: REAL 🐶  |  Probability: 0.00
# Image 697: REAL 🐶  |  Probability: 0.00
# Image 698: REAL 🐶  |  Probability: 0.00
# Image 699: REAL 🐶  |  Probability: 0.00
# Image 700: REAL 🐶  |  Probability: 0.00
# Image 701: REAL 🐶  |  Probability: 0.00
# Image 702: REAL 🐶  |  Probability: 0.00
# Image 703: REAL 🐶  |  Probability: 0.01
# Image 704: REAL 🐶  |  Probability: 0.00
# Image 705: REAL 🐶  |  Probability: 0.00
# Image 706: REAL 🐶  |  Probability: 0.00
# Image 707: REAL 🐶  |  Probability: 0.00
# Image 708: REAL 🐶  |  Probability: 0.00
# Image 709: REAL 🐶  |  Probability: 0.00
# Image 710: REAL 🐶  |  Probability: 0.00
# Image 772: REAL 🐶  |  Probability: 0.00
# Image 773: REAL 🐶  |  Probability: 0.00
# Image 774: REAL 🐶  |  Probability: 0.00
# Image 775: REAL 🐶  |  Probability: 0.00
# Image 776: REAL 🐶  |  Probability: 0.00
# Image 777: REAL 🐶  |  Probability: 0.01
# Image 778: REAL 🐶  |  Probability: 0.00
# Image 779: REAL 🐶  |  Probability: 0.00
# Image 780: REAL 🐶  |  Probability: 0.01
# Image 781: REAL 🐶  |  Probability: 0.00
# Image 782: REAL 🐶  |  Probability: 0.00
# Image 783: REAL 🐶  |  Probability: 0.00
# Image 784: REAL 🐶  |  Probability: 0.00
# Image 785: REAL 🐶  |  Probability: 0.00
# Image 786: REAL 🐶  |  Probability: 0.00
# Image 787: REAL 🐶  |  Probability: 0.00
# Image 788: REAL 🐶  |  Probability: 0.04
# Image 789: REAL 🐶  |  Probability: 0.00
# Image 790: REAL 🐶  |  Probability: 0.00
# Image 791: REAL 🐶  |  Probability: 0.02
# Image 792: REAL 🐶  |  Probability: 0.00
# Image 793: REAL 🐶  |  Probability: 0.00
# Image 794: REAL 🐶  |  Probability: 0.00
# Image 795: REAL 🐶  |  Probability: 0.00
# Image 796: REAL 🐶  |  Probability: 0.00
# Image 797: REAL 🐶  |  Probability: 0.00
# Image 798: REAL 🐶  |  Probability: 0.00
# Image 799: REAL 🐶  |  Probability: 0.00
# Image 800: REAL 🐶  |  Probability: 0.00
# Image 801: REAL 🐶  |  Probability: 0.00
# Image 802: REAL 🐶  |  Probability: 0.01
# Image 803: REAL 🐶  |  Probability: 0.03
# Image 804: REAL 🐶  |  Probability: 0.00
# Image 805: REAL 🐶  |  Probability: 0.00
# Image 806: REAL 🐶  |  Probability: 0.07
# Image 807: REAL 🐶  |  Probability: 0.00
# Image 808: REAL 🐶  |  Probability: 0.09
# Image 809: REAL 🐶  |  Probability: 0.00
# Image 810: REAL 🐶  |  Probability: 0.01
# Image 811: REAL 🐶  |  Probability: 0.00
# Image 812: REAL 🐶  |  Probability: 0.17
# Image 813: REAL 🐶  |  Probability: 0.00
# Image 814: REAL 🐶  |  Probability: 0.00
# Image 815: REAL 🐶  |  Probability: 0.00
# Image 816: AI-GENERATED 🤖  |  Probability: 0.81
# Image 817: REAL 🐶  |  Probability: 0.00
# Image 818: REAL 🐶  |  Probability: 0.00
# Image 819: REAL 🐶  |  Probability: 0.00
# Image 820: REAL 🐶  |  Probability: 0.14
# Image 821: REAL 🐶  |  Probability: 0.00
# Image 822: REAL 🐶  |  Probability: 0.00
# Image 823: REAL 🐶  |  Probability: 0.00
# Image 824: REAL 🐶  |  Probability: 0.00
# Image 825: REAL 🐶  |  Probability: 0.00
# Image 826: REAL 🐶  |  Probability: 0.00
# Image 827: REAL 🐶  |  Probability: 0.00
# Image 828: REAL 🐶  |  Probability: 0.00
# Image 829: REAL 🐶  |  Probability: 0.00
# Image 830: REAL 🐶  |  Probability: 0.00
# Image 831: REAL 🐶  |  Probability: 0.00
# Image 832: REAL 🐶  |  Probability: 0.00
# Image 833: REAL 🐶  |  Probability: 0.00
# Image 834: REAL 🐶  |  Probability: 0.00
# Image 835: REAL 🐶  |  Probability: 0.00
# Image 836: REAL 🐶  |  Probability: 0.00
# Image 837: REAL 🐶  |  Probability: 0.00
# Image 838: REAL 🐶  |  Probability: 0.00
# Image 839: REAL 🐶  |  Probability: 0.00
# Image 840: REAL 🐶  |  Probability: 0.00
# Image 841: REAL 🐶  |  Probability: 0.00
# Image 842: REAL 🐶  |  Probability: 0.00
# Image 843: REAL 🐶  |  Probability: 0.00
# Image 844: REAL 🐶  |  Probability: 0.00
# Image 845: REAL 🐶  |  Probability: 0.00
# Image 846: REAL 🐶  |  Probability: 0.05
# Image 847: REAL 🐶  |  Probability: 0.00
# Image 848: REAL 🐶  |  Probability: 0.00
# Image 849: REAL 🐶  |  Probability: 0.00
# Image 850: REAL 🐶  |  Probability: 0.00
# Image 851: REAL 🐶  |  Probability: 0.00
# Image 852: REAL 🐶  |  Probability: 0.00
# Image 853: REAL 🐶  |  Probability: 0.00
# Image 854: REAL 🐶  |  Probability: 0.00
# Image 855: REAL 🐶  |  Probability: 0.00
# Image 856: REAL 🐶  |  Probability: 0.00
# Image 857: REAL 🐶  |  Probability: 0.00
# Image 858: REAL 🐶  |  Probability: 0.00
# Image 859: REAL 🐶  |  Probability: 0.00
# Image 860: REAL 🐶  |  Probability: 0.00
# Image 861: REAL 🐶  |  Probability: 0.00
# Image 862: REAL 🐶  |  Probability: 0.00
# Image 863: REAL 🐶  |  Probability: 0.00
# Image 864: REAL 🐶  |  Probability: 0.00
# Image 865: REAL 🐶  |  Probability: 0.00
# Image 866: REAL 🐶  |  Probability: 0.00
# Image 867: REAL 🐶  |  Probability: 0.00
# Image 868: REAL 🐶  |  Probability: 0.00
# Image 869: REAL 🐶  |  Probability: 0.00
# Image 870: REAL 🐶  |  Probability: 0.00
# Image 871: REAL 🐶  |  Probability: 0.00
# Image 872: REAL 🐶  |  Probability: 0.00
# Image 873: REAL 🐶  |  Probability: 0.00
# Image 874: REAL 🐶  |  Probability: 0.00
# Image 875: REAL 🐶  |  Probability: 0.00
# Image 876: REAL 🐶  |  Probability: 0.00
# Image 877: REAL 🐶  |  Probability: 0.00
# Image 878: REAL 🐶  |  Probability: 0.00
# Image 879: REAL 🐶  |  Probability: 0.00
# Image 880: REAL 🐶  |  Probability: 0.00
# Image 881: REAL 🐶  |  Probability: 0.00
# Image 882: REAL 🐶  |  Probability: 0.00
# Image 883: REAL 🐶  |  Probability: 0.00
# ...
# Image 2269: REAL 🐶  |  Probability: 0.00
# Image 2270: REAL 🐶  |  Probability: 0.00
# Image 2271: REAL 🐶  |  Probability: 0.00
# Image 2272: REAL 🐶  |  Probability: 0.00
# Image 2273: REAL 🐶  |  Probability: 0.00
# Image 2274: REAL 🐶  |  Probability: 0.03
# Image 2275: REAL 🐶  |  Probability: 0.00
# Image 2276: REAL 🐶  |  Probability: 0.00
# Image 2277: REAL 🐶  |  Probability: 0.00
# Image 2278: REAL 🐶  |  Probability: 0.00
# Image 2279: REAL 🐶  |  Probability: 0.00
# Image 2280: REAL 🐶  |  Probability: 0.00
# Image 2281: REAL 🐶  |  Probability: 0.00
# Image 2282: REAL 🐶  |  Probability: 0.00
# Image 2283: REAL 🐶  |  Probability: 0.00
# Image 2284: REAL 🐶  |  Probability: 0.00
# Image 2285: AI-GENERATED 🤖  |  Probability: 0.96
# Image 2286: REAL 🐶  |  Probability: 0.00
# Image 2287: REAL 🐶  |  Probability: 0.00
# Image 2288: REAL 🐶  |  Probability: 0.00
# Image 2289: REAL 🐶  |  Probability: 0.00
# Image 2290: REAL 🐶  |  Probability: 0.00
# Image 2291: REAL 🐶  |  Probability: 0.00
# Image 2292: REAL 🐶  |  Probability: 0.00
# Image 2293: REAL 🐶  |  Probability: 0.00
# Image 2294: REAL 🐶  |  Probability: 0.00
# Image 2295: REAL 🐶  |  Probability: 0.00
# Image 2296: REAL 🐶  |  Probability: 0.00
# Image 2297: REAL 🐶  |  Probability: 0.00
# Image 2298: REAL 🐶  |  Probability: 0.00
# Image 2299: REAL 🐶  |  Probability: 0.00
# Image 2300: REAL 🐶  |  Probability: 0.00
# Image 2301: REAL 🐶  |  Probability: 0.00
# Image 2302: REAL 🐶  |  Probability: 0.00
# Image 2303: REAL 🐶  |  Probability: 0.00
# Image 2304: REAL 🐶  |  Probability: 0.00
# Image 2305: REAL 🐶  |  Probability: 0.00
# Image 2306: REAL 🐶  |  Probability: 0.00
# Image 2307: REAL 🐶  |  Probability: 0.00
# Image 2308: REAL 🐶  |  Probability: 0.00
# Image 2309: REAL 🐶  |  Probability: 0.00
# Image 2310: REAL 🐶  |  Probability: 0.00
# Image 2311: REAL 🐶  |  Probability: 0.00
# Image 2312: REAL 🐶  |  Probability: 0.00
# Image 2313: REAL 🐶  |  Probability: 0.00
# Image 2314: REAL 🐶  |  Probability: 0.00
# Image 2315: REAL 🐶  |  Probability: 0.00
# Image 2316: REAL 🐶  |  Probability: 0.00
# Image 2317: REAL 🐶  |  Probability: 0.00
# Image 2318: REAL 🐶  |  Probability: 0.00
# Image 2319: REAL 🐶  |  Probability: 0.00
# Image 2320: REAL 🐶  |  Probability: 0.00
# Image 2321: REAL 🐶  |  Probability: 0.02
# Image 2322: REAL 🐶  |  Probability: 0.00
# Image 2323: REAL 🐶  |  Probability: 0.00
# Image 2324: REAL 🐶  |  Probability: 0.00
# Image 2325: REAL 🐶  |  Probability: 0.00
# Image 2326: REAL 🐶  |  Probability: 0.01
# Image 2327: REAL 🐶  |  Probability: 0.00
# Image 2328: REAL 🐶  |  Probability: 0.00
# Image 2329: REAL 🐶  |  Probability: 0.00
# Image 2330: REAL 🐶  |  Probability: 0.00
# Image 2331: REAL 🐶  |  Probability: 0.00
# Image 2332: REAL 🐶  |  Probability: 0.00
# Image 2333: REAL 🐶  |  Probability: 0.00
# Image 2334: REAL 🐶  |  Probability: 0.00
# Image 2335: REAL 🐶  |  Probability: 0.00
# Image 2336: REAL 🐶  |  Probability: 0.00
# Image 2337: REAL 🐶  |  Probability: 0.00
# Image 2338: REAL 🐶  |  Probability: 0.00
# Image 2339: REAL 🐶  |  Probability: 0.00
# Image 2340: REAL 🐶  |  Probability: 0.00
# Image 2341: REAL 🐶  |  Probability: 0.00
# Image 2342: REAL 🐶  |  Probability: 0.00
# Image 2343: REAL 🐶  |  Probability: 0.01
# Image 2344: REAL 🐶  |  Probability: 0.00
# Image 2345: REAL 🐶  |  Probability: 0.00
# Image 2346: REAL 🐶  |  Probability: 0.00
# Image 2347: REAL 🐶  |  Probability: 0.00
# Image 2348: REAL 🐶  |  Probability: 0.00
# Image 2349: REAL 🐶  |  Probability: 0.28
# Image 2350: REAL 🐶  |  Probability: 0.00
# Image 2351: REAL 🐶  |  Probability: 0.00
# Image 2352: REAL 🐶  |  Probability: 0.00
# Image 2353: REAL 🐶  |  Probability: 0.01
# Image 2354: REAL 🐶  |  Probability: 0.00
# Image 2355: REAL 🐶  |  Probability: 0.00
# Image 2356: REAL 🐶  |  Probability: 0.00
# Image 2357: REAL 🐶  |  Probability: 0.00
# Image 2358: REAL 🐶  |  Probability: 0.00
# Image 2359: REAL 🐶  |  Probability: 0.00
# Image 2360: REAL 🐶  |  Probability: 0.00
# Image 2361: REAL 🐶  |  Probability: 0.00
# Image 2362: REAL 🐶  |  Probability: 0.00
# Image 2363: REAL 🐶  |  Probability: 0.00
# Image 2364: REAL 🐶  |  Probability: 0.00
# Image 2365: REAL 🐶  |  Probability: 0.00
# Image 2366: REAL 🐶  |  Probability: 0.00
# Image 2367: REAL 🐶  |  Probability: 0.00
# Image 2368: REAL 🐶  |  Probability: 0.00
# Image 2369: REAL 🐶  |  Probability: 0.00
# Image 2370: REAL 🐶  |  Probability: 0.00
# Image 2371: REAL 🐶  |  Probability: 0.00
# Image 2372: REAL 🐶  |  Probability: 0.00
# Image 2373: REAL 🐶  |  Probability: 0.00
# Image 2374: REAL 🐶  |  Probability: 0.00
# Image 2375: REAL 🐶  |  Probability: 0.00
# Image 2376: REAL 🐶  |  Probability: 0.00
# Image 2377: REAL 🐶  |  Probability: 0.00
# Image 2378: REAL 🐶  |  Probability: 0.00
# Image 2379: REAL 🐶  |  Probability: 0.00
# Image 2380: REAL 🐶  |  Probability: 0.00
# Image 2381: REAL 🐶  |  Probability: 0.00
# Image 2382: REAL 🐶  |  Probability: 0.00
# Image 2383: REAL 🐶  |  Probability: 0.00
# Image 2384: REAL 🐶  |  Probability: 0.00
# Image 2385: REAL 🐶  |  Probability: 0.00
# Image 2386: REAL 🐶  |  Probability: 0.00
# Image 2387: REAL 🐶  |  Probability: 0.00
# Image 2388: REAL 🐶  |  Probability: 0.00
# Image 2389: REAL 🐶  |  Probability: 0.00
# Image 2390: REAL 🐶  |  Probability: 0.00
# Image 2391: REAL 🐶  |  Probability: 0.00
# Image 2392: REAL 🐶  |  Probability: 0.01
# Image 2393: REAL 🐶  |  Probability: 0.00
# Image 2394: REAL 🐶  |  Probability: 0.00
# Image 2395: REAL 🐶  |  Probability: 0.00
# Image 2396: REAL 🐶  |  Probability: 0.00
# Image 2397: REAL 🐶  |  Probability: 0.00
# Image 2398: REAL 🐶  |  Probability: 0.06
# Image 2399: REAL 🐶  |  Probability: 0.00
# Image 2400: REAL 🐶  |  Probability: 0.00
# Image 2401: REAL 🐶  |  Probability: 0.00
# Image 2402: REAL 🐶  |  Probability: 0.00
# Image 2403: REAL 🐶  |  Probability: 0.00
# Image 2404: REAL 🐶  |  Probability: 0.00
# Image 2405: REAL 🐶  |  Probability: 0.00
# Image 2406: REAL 🐶  |  Probability: 0.00
# Image 2407: REAL 🐶  |  Probability: 0.00
# Image 2408: REAL 🐶  |  Probability: 0.00
# Image 2409: REAL 🐶  |  Probability: 0.00
# Image 2410: REAL 🐶  |  Probability: 0.00
# Image 2411: REAL 🐶  |  Probability: 0.00
# Image 2412: REAL 🐶  |  Probability: 0.00
# Image 2413: REAL 🐶  |  Probability: 0.00
# Image 2414: REAL 🐶  |  Probability: 0.00
# Image 2415: REAL 🐶  |  Probability: 0.00
# Image 2416: REAL 🐶  |  Probability: 0.00
# Image 2417: REAL 🐶  |  Probability: 0.00
# Image 2418: REAL 🐶  |  Probability: 0.00
# Image 2419: REAL 🐶  |  Probability: 0.00
# Image 2420: REAL 🐶  |  Probability: 0.00
# Image 2421: REAL 🐶  |  Probability: 0.00
# Image 2422: REAL 🐶  |  Probability: 0.00
# Image 2423: REAL 🐶  |  Probability: 0.00
# Image 2424: REAL 🐶  |  Probability: 0.00
# Image 2425: REAL 🐶  |  Probability: 0.00
# Image 2426: REAL 🐶  |  Probability: 0.00
# Image 2427: REAL 🐶  |  Probability: 0.00
# Image 2428: REAL 🐶  |  Probability: 0.00
# Image 2429: REAL 🐶  |  Probability: 0.00
# Image 2430: REAL 🐶  |  Probability: 0.00
# Image 2431: REAL 🐶  |  Probability: 0.00
# Image 2432: REAL 🐶  |  Probability: 0.00
# Image 2433: REAL 🐶  |  Probability: 0.00
# Image 2434: REAL 🐶  |  Probability: 0.00
# Image 2435: REAL 🐶  |  Probability: 0.00
# Image 2436: REAL 🐶  |  Probability: 0.00
# Image 2437: REAL 🐶  |  Probability: 0.00
# Image 2438: REAL 🐶  |  Probability: 0.00
# Image 2439: REAL 🐶  |  Probability: 0.00
# Image 2440: REAL 🐶  |  Probability: 0.00
# Image 2441: REAL 🐶  |  Probability: 0.00
# Image 2442: REAL 🐶  |  Probability: 0.00
# Image 2443: REAL 🐶  |  Probability: 0.00
# Image 2444: REAL 🐶  |  Probability: 0.24
# Image 2445: REAL 🐶  |  Probability: 0.00
# Image 2446: REAL 🐶  |  Probability: 0.00
# Image 2447: REAL 🐶  |  Probability: 0.00
# Image 2448: REAL 🐶  |  Probability: 0.00
# Image 2449: REAL 🐶  |  Probability: 0.00
# Image 2450: REAL 🐶  |  Probability: 0.00
# Image 2451: REAL 🐶  |  Probability: 0.00
# Image 2452: REAL 🐶  |  Probability: 0.00
# Image 2453: REAL 🐶  |  Probability: 0.00
# Image 2454: REAL 🐶  |  Probability: 0.00
# Image 2455: REAL 🐶  |  Probability: 0.00
# Image 2456: REAL 🐶  |  Probability: 0.00
# Image 2457: REAL 🐶  |  Probability: 0.00
# Image 2458: REAL 🐶  |  Probability: 0.00
# Image 2459: REAL 🐶  |  Probability: 0.00
# Image 2460: REAL 🐶  |  Probability: 0.00
# Image 2461: REAL 🐶  |  Probability: 0.00
# Image 2462: REAL 🐶  |  Probability: 0.00
# Image 2463: REAL 🐶  |  Probability: 0.00
# Image 2464: REAL 🐶  |  Probability: 0.00
# Image 2465: REAL 🐶  |  Probability: 0.00
# Image 2466: REAL 🐶  |  Probability: 0.00
# Image 2467: REAL 🐶  |  Probability: 0.00
# Image 2468: REAL 🐶  |  Probability: 0.00
# Image 2469: REAL 🐶  |  Probability: 0.00
# Image 2470: REAL 🐶  |  Probability: 0.00
# Image 2471: REAL 🐶  |  Probability: 0.00
# Image 2472: REAL 🐶  |  Probability: 0.00
# Image 2473: REAL 🐶  |  Probability: 0.00
# Image 2474: REAL 🐶  |  Probability: 0.00
# Image 2475: REAL 🐶  |  Probability: 0.00
# Image 2476: REAL 🐶  |  Probability: 0.00
# Image 2477: REAL 🐶  |  Probability: 0.00
# Image 2478: REAL 🐶  |  Probability: 0.00
# Image 2479: REAL 🐶  |  Probability: 0.00
# Image 2480: REAL 🐶  |  Probability: 0.00
# Image 2481: REAL 🐶  |  Probability: 0.00
# Image 2482: REAL 🐶  |  Probability: 0.00
# Image 2483: REAL 🐶  |  Probability: 0.00
# Image 2484: REAL 🐶  |  Probability: 0.00
# Image 2485: REAL 🐶  |  Probability: 0.00
# Image 2486: REAL 🐶  |  Probability: 0.00
# Image 2487: REAL 🐶  |  Probability: 0.00
# Image 2488: REAL 🐶  |  Probability: 0.00
# Image 2489: REAL 🐶  |  Probability: 0.00
# Image 2490: REAL 🐶  |  Probability: 0.00
# Image 2491: REAL 🐶  |  Probability: 0.00
# Image 2492: REAL 🐶  |  Probability: 0.00
# Image 2493: REAL 🐶  |  Probability: 0.04
# Image 2494: REAL 🐶  |  Probability: 0.00
# Image 2495: REAL 🐶  |  Probability: 0.00
# Image 2496: REAL 🐶  |  Probability: 0.00
# Image 2497: REAL 🐶  |  Probability: 0.00
# Image 2498: REAL 🐶  |  Probability: 0.00
# Image 2499: REAL 🐶  |  Probability: 0.00
# Image 2500: REAL 🐶  |  Probability: 0.00
# Image 2501: REAL 🐶  |  Probability: 0.00
# Image 2502: REAL 🐶  |  Probability: 0.00
# Image 2503: REAL 🐶  |  Probability: 0.01
# Image 2504: REAL 🐶  |  Probability: 0.00
# Image 2505: REAL 🐶  |  Probability: 0.00
# Image 2506: REAL 🐶  |  Probability: 0.00
# Image 2507: REAL 🐶  |  Probability: 0.00
# Image 2508: REAL 🐶  |  Probability: 0.00
# Image 2509: REAL 🐶  |  Probability: 0.00
# Image 2510: REAL 🐶  |  Probability: 0.00
# Image 2511: REAL 🐶  |  Probability: 0.00
# Image 2512: REAL 🐶  |  Probability: 0.00
# Image 2513: REAL 🐶  |  Probability: 0.02
# Image 2514: REAL 🐶  |  Probability: 0.00
# Image 2515: REAL 🐶  |  Probability: 0.00
# Image 2516: REAL 🐶  |  Probability: 0.00
# Image 2517: REAL 🐶  |  Probability: 0.00
# Image 2518: REAL 🐶  |  Probability: 0.00
# Image 2519: REAL 🐶  |  Probability: 0.00
# Image 2520: REAL 🐶  |  Probability: 0.00
# Image 2521: REAL 🐶  |  Probability: 0.00
# Image 2522: REAL 🐶  |  Probability: 0.00
# Image 2523: REAL 🐶  |  Probability: 0.00
# Image 2524: REAL 🐶  |  Probability: 0.00
# Image 2525: REAL 🐶  |  Probability: 0.00
# Image 2526: REAL 🐶  |  Probability: 0.00
# Image 2527: REAL 🐶  |  Probability: 0.00
# Image 2528: REAL 🐶  |  Probability: 0.00
# Image 2529: REAL 🐶  |  Probability: 0.00
# Image 2530: REAL 🐶  |  Probability: 0.00
# Image 2531: REAL 🐶  |  Probability: 0.00
# Image 2532: REAL 🐶  |  Probability: 0.00
# Image 2533: REAL 🐶  |  Probability: 0.00
# Image 2534: REAL 🐶  |  Probability: 0.00
# Image 2535: REAL 🐶  |  Probability: 0.00
# Image 2536: REAL 🐶  |  Probability: 0.00
# Image 2537: REAL 🐶  |  Probability: 0.00
# Image 2538: REAL 🐶  |  Probability: 0.00
# Image 2539: REAL 🐶  |  Probability: 0.00
# Image 2540: REAL 🐶  |  Probability: 0.00
# Image 2541: REAL 🐶  |  Probability: 0.00
# Image 2542: REAL 🐶  |  Probability: 0.01
# Image 2543: REAL 🐶  |  Probability: 0.00
# Image 2544: REAL 🐶  |  Probability: 0.00
# Image 2545: REAL 🐶  |  Probability: 0.00
# Image 2546: REAL 🐶  |  Probability: 0.00
# Image 2547: REAL 🐶  |  Probability: 0.00
# Image 2548: REAL 🐶  |  Probability: 0.00
# Image 2549: REAL 🐶  |  Probability: 0.00
# Image 2550: REAL 🐶  |  Probability: 0.00
# Image 2551: REAL 🐶  |  Probability: 0.00
# Image 2552: REAL 🐶  |  Probability: 0.00
# Image 2553: REAL 🐶  |  Probability: 0.00
# Image 2554: REAL 🐶  |  Probability: 0.00
# Image 2555: REAL 🐶  |  Probability: 0.00
# Image 2556: REAL 🐶  |  Probability: 0.00
# Image 2557: REAL 🐶  |  Probability: 0.00
# Image 2558: REAL 🐶  |  Probability: 0.00
# Image 2559: REAL 🐶  |  Probability: 0.00
# Image 2560: REAL 🐶  |  Probability: 0.00
# Image 2561: REAL 🐶  |  Probability: 0.00
# Image 2562: REAL 🐶  |  Probability: 0.00
# Image 2563: REAL 🐶  |  Probability: 0.00
# Image 2564: REAL 🐶  |  Probability: 0.00
# Image 2565: REAL 🐶  |  Probability: 0.00
# Image 2566: REAL 🐶  |  Probability: 0.00
# Image 2567: REAL 🐶  |  Probability: 0.00
# Image 2568: REAL 🐶  |  Probability: 0.00
# Image 2569: REAL 🐶  |  Probability: 0.00
# Image 2570: REAL 🐶  |  Probability: 0.00
# Image 2571: REAL 🐶  |  Probability: 0.00
# Image 2572: REAL 🐶  |  Probability: 0.00
# Image 2573: REAL 🐶  |  Probability: 0.00
# Image 2574: REAL 🐶  |  Probability: 0.00
# Image 2575: REAL 🐶  |  Probability: 0.00
# Image 2576: REAL 🐶  |  Probability: 0.00
# Image 2577: REAL 🐶  |  Probability: 0.00
# Image 2578: REAL 🐶  |  Probability: 0.00
# Image 2579: REAL 🐶  |  Probability: 0.00
# Image 2580: REAL 🐶  |  Probability: 0.00
# Image 2581: REAL 🐶  |  Probability: 0.00
# Image 2582: REAL 🐶  |  Probability: 0.01
# Image 2583: REAL 🐶  |  Probability: 0.00
# Image 2584: REAL 🐶  |  Probability: 0.00
# Image 2585: REAL 🐶  |  Probability: 0.00
# Image 2586: REAL 🐶  |  Probability: 0.00
# Image 2587: REAL 🐶  |  Probability: 0.00
# Image 2588: REAL 🐶  |  Probability: 0.00
# Image 2589: REAL 🐶  |  Probability: 0.00
# Image 2590: REAL 🐶  |  Probability: 0.00
# Image 2591: REAL 🐶  |  Probability: 0.00
# Image 2592: REAL 🐶  |  Probability: 0.00
# Image 2593: REAL 🐶  |  Probability: 0.00
# Image 2594: REAL 🐶  |  Probability: 0.00
# Image 2595: REAL 🐶  |  Probability: 0.00
# Image 2596: REAL 🐶  |  Probability: 0.00
# Image 2597: REAL 🐶  |  Probability: 0.00
# Image 2598: REAL 🐶  |  Probability: 0.00
# Image 2599: REAL 🐶  |  Probability: 0.00
# Image 2600: REAL 🐶  |  Probability: 0.00
# Image 2601: REAL 🐶  |  Probability: 0.00
# Image 2602: REAL 🐶  |  Probability: 0.00
# Image 2603: REAL 🐶  |  Probability: 0.21
# Image 2604: REAL 🐶  |  Probability: 0.00
# Image 2605: REAL 🐶  |  Probability: 0.00
# Image 2606: REAL 🐶  |  Probability: 0.00
# Image 2607: REAL 🐶  |  Probability: 0.00
# Image 2608: REAL 🐶  |  Probability: 0.00
# Image 2609: REAL 🐶  |  Probability: 0.00
# Image 2610: REAL 🐶  |  Probability: 0.00
# Image 2611: REAL 🐶  |  Probability: 0.00
# Image 2612: REAL 🐶  |  Probability: 0.00
# Image 2613: REAL 🐶  |  Probability: 0.00
# Image 2614: REAL 🐶  |  Probability: 0.00
# Image 2615: REAL 🐶  |  Probability: 0.00
# Image 2616: REAL 🐶  |  Probability: 0.00
# Image 2617: REAL 🐶  |  Probability: 0.00
# Image 2618: REAL 🐶  |  Probability: 0.00
# Image 2619: REAL 🐶  |  Probability: 0.00
# Image 2620: REAL 🐶  |  Probability: 0.00
# Image 2621: REAL 🐶  |  Probability: 0.00
# Image 2622: REAL 🐶  |  Probability: 0.00
# Image 2623: REAL 🐶  |  Probability: 0.00
# Image 2624: REAL 🐶  |  Probability: 0.00
# Image 2625: REAL 🐶  |  Probability: 0.00
# Image 2626: REAL 🐶  |  Probability: 0.00
# Image 2627: REAL 🐶  |  Probability: 0.00
# Image 2628: REAL 🐶  |  Probability: 0.00
# Image 2629: REAL 🐶  |  Probability: 0.00
# Image 2630: REAL 🐶  |  Probability: 0.00
# Image 2631: REAL 🐶  |  Probability: 0.00
# Image 2632: REAL 🐶  |  Probability: 0.00
# Image 2633: REAL 🐶  |  Probability: 0.00
# Image 2634: REAL 🐶  |  Probability: 0.00
# Image 2635: REAL 🐶  |  Probability: 0.00
# Image 2636: REAL 🐶  |  Probability: 0.00
# Image 2637: REAL 🐶  |  Probability: 0.00
# Image 2638: REAL 🐶  |  Probability: 0.00
# Image 2639: REAL 🐶  |  Probability: 0.00
# Image 2640: REAL 🐶  |  Probability: 0.00
# Image 2641: REAL 🐶  |  Probability: 0.00
# Image 2642: REAL 🐶  |  Probability: 0.00
# Image 2643: REAL 🐶  |  Probability: 0.00
# Image 2644: REAL 🐶  |  Probability: 0.00
# Image 2645: REAL 🐶  |  Probability: 0.00
# Image 2646: REAL 🐶  |  Probability: 0.00
# Image 2647: REAL 🐶  |  Probability: 0.00
# Image 2648: REAL 🐶  |  Probability: 0.00
# Image 2649: REAL 🐶  |  Probability: 0.00
# Image 2650: REAL 🐶  |  Probability: 0.00
# Image 2651: REAL 🐶  |  Probability: 0.00
# Image 2652: REAL 🐶  |  Probability: 0.00
# Image 2653: REAL 🐶  |  Probability: 0.00
# Image 2654: REAL 🐶  |  Probability: 0.00
# Image 2655: REAL 🐶  |  Probability: 0.00
# Image 2656: REAL 🐶  |  Probability: 0.00
# Image 2657: REAL 🐶  |  Probability: 0.00
# Image 2658: REAL 🐶  |  Probability: 0.00

# %%
import io
from PIL import Image
from torchvision import transforms
from transformers import AutoFeatureExtractor, AutoModel
import torch.nn as nn
import torch.nn.functional as F
import ipywidgets as widgets
from IPython.display import display

# Upload image
uploader = widgets.FileUpload(accept='image/*', multiple=False)
display(uploader)

# Load feature extractor and backbone
extractor = AutoFeatureExtractor.from_pretrained("google/vit-base-patch16-224-in21k")
feature_model = AutoModel.from_pretrained("google/vit-base-patch16-224-in21k").to(device)

# Load classifier
model = load_model("plusdiff_model.pt").to(device)

# Quick projection from 768 → 384 (simulates training setup)
projection = nn.Linear(768, 384).to(device)

def extract_features(image):
    # Step 1: Extract 768-dim features from ViT
    inputs = extractor(images=image, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        vit_features = feature_model(**inputs).last_hidden_state.mean(dim=1)

    # Step 2: Project down to 384
    projected = projection(vit_features)

    # Step 3: Pad to 385
    padding = torch.zeros((projected.shape[0], 1), device=device)
    features_385 = torch.cat([projected, padding], dim=1)

    return features_385

def classify_uploaded_image(change):
    if len(uploader.value) > 0:
        file_info = list(uploader.value.values())[0]
        image_bytes = file_info['content']
        image = Image.open(io.BytesIO(image_bytes)).convert("RGB")
        display(image)

        # Extract and classify
        features = extract_features(image)
        with torch.no_grad():
            output = model(features)
            prob = torch.sigmoid(output).item()
            label = "AI-generated 🤖" if prob > 0.5 else "Real 🐶"
        print(f"Prediction: {label} (Confidence: {prob:.2f})")

uploader.observe(classify_uploaded_image, names='value')
# Out:
# FileUpload(value={}, accept='image/*', description='Upload')
# <PIL.Image.Image image mode=RGB size=1200x800>
# Prediction: Real 🐶 (Confidence: 0.00)
